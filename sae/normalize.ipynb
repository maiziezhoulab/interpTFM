# %%
import sys
from pathlib import Path
sys.path.append(str(Path("./").resolve().parent))
from normalize import normalize_sae_features

# %%
# Loop through all 12 layers and train SAE on each
for layer in range(12):
    gfm_embd_dir = f"/maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/activations/layer_{layer}"
    sae_dir = f"/maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer{layer+1}"
    # print(f"=== Training SAE on layer {layer} embeddings ===")
    normalize_sae_features(sae_dir=Path(sae_dir), embds_dir=Path(gfm_embd_dir), n_shards=60)
    # print(f"Finished training SAE on layer {layer}, results saved to {save_dir}\n")
# Out:
# Loading SAE model and calculating feature statistics...
# Creating normalized SAE model...
# Normalized model saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer1/ae_normalized.pt
# Loading SAE model and calculating feature statistics...
# Creating normalized SAE model...
# Normalized model saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer2/ae_normalized.pt
# Loading SAE model and calculating feature statistics...
# Creating normalized SAE model...
# Normalized model saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer3/ae_normalized.pt
# Loading SAE model and calculating feature statistics...
# Creating normalized SAE model...
# Normalized model saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer4/ae_normalized.pt
# ...

# %%
sae_dir='/maiziezhou_lab2/yunfei/Projects/FM_temp/interGFM/sae/sae_output_layer4'
embds_dir='/maiziezhou_lab2/yunfei/Projects/FM_temp/InterPLM/interplm/scgpt/activations/layer_4'

# %%
normalize_sae_features(sae_dir=Path(sae_dir), embds_dir=Path(embds_dir), n_shards=20)
# Out:
# Loading SAE model and calculating feature statistics...
# Creating normalized SAE model...
# Normalized model saved to /maiziezhou_lab2/yunfei/Projects/FM_temp/interGFM/sae/sae_output_layer4/ae_normalized.pt
