# %%
"""
Script for training SAE from a cache of scgpt activations and loading the custom fidelity function.

"""

import warnings
from pathlib import Path
import sys
sys.path.append(str(Path("./").resolve().parent))

import torch
from torch.utils.data import DataLoader

from sae.dictionary import AutoEncoder
from fidelity import get_loss_recovery_fn
from load_sharded_acts import LazyMultiDirectoryTokenDataset
from trainer import StandardTrainer
from training import train_run
from typing import Optional

warnings.filterwarnings("ignore", message="TypedStorage is deprecated")

def get_device() -> str:
    if torch.cuda.is_available():
        return "cuda"
    else:
        return "cpu"


def train_SAE_on_gfm_embeds(
    # Data paths and sources
    gfm_embd_dir: Path,
    eval_seq_path: Optional[Path] = None,
    # Core model architecture
    expansion_factor: int = 8,
    # Training configuration
    batch_size: int = 32,
    steps: int = 2_000,
    seed: int = 0,
    # Optimization parameters
    lr: float = 1e-3,
    warmup_steps: int = 50,
    resample_steps: int = 0,  # 0 to disable
    # Regularization
    l1_penalty: float = 1e-1,
    l1_annealing_pct: float = 0.05,
    # Evaluation settings
    eval_batch_size: int = 128,
    eval_steps: int = 1_000,
    # Logging and checkpointing
    save_dir: str = "models",
    log_steps: int = 100,
    save_steps: int = 50,
    max_ckpts_to_keep: int = 3,
    # Weights & Biases configuration
    use_wandb: bool = True,
    wandb_entity: str = "yunfei-hu-vanderbilt-university",
    wandb_project: str = "test_logging",
    wandb_name: str = "SAE",
):
    """
    Train a Sparse Autoencoder (SAE) using cached activation data from a language model.

    Args:
        # Data paths and sources
        gfm_embd_dir: Directory containing cached model embeddings
        eval_seq_path: Path to sequences for fidelity evaluation, if None, fidelity evaluation is disabled

        # Core model architecture
        expansion_factor: Factor by which to expand the dictionary size relative to input dimension

        # Training configuration
        batch_size: Number of samples per training batch
        steps: Total number of training steps
        seed: Random seed for reproducibility

        # Optimization parameters
        lr: Learning rate for optimizer
        warmup_steps: Number of warmup steps for learning rate scheduler
        resample_steps: Steps between dictionary resampling (0 to disable)

        # Regularization
        l1_penalty: Coefficient for L1 regularization
        l1_annealing_pct: Percentage of training during which to anneal L1 penalty

        # Evaluation settings
        eval_batch_size: Batch size for evaluation
        eval_steps: Frequency of evaluation steps

        # Logging and checkpointing
        save_dir: Directory to save model checkpoints and outputs
        log_steps: Frequency of logging
        save_steps: Frequency of saving checkpoints

        # Weights & Biases configuration
        use_wandb: Whether to use Weights & Biases logging
        wandb_entity: W&B username or team name
        wandb_project: W&B project name
        wandb_name: W&B run name
    """
    device = get_device()

    def collate_fn(batch):
        return torch.stack(batch).to(device)

    # Initialize dataset and dataloader
    acts_dataset = LazyMultiDirectoryTokenDataset(gfm_embd_dir)

    # Determine layer from dataset metadata
    layer = acts_dataset.datasets[0]["layer"]
    plm_name = acts_dataset.datasets[0]["plm_name"]
    print(f"Using activations from layer {layer} of {plm_name}")

    dataloader = DataLoader(
        acts_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn
    )
    print(f"Loaded dataset with {len(acts_dataset):,} tokens")

    # Configure resampling
    if resample_steps == 0:
        resample_steps = None

    # Setup trainer configuration
    trainer = StandardTrainer(
        activation_dim=acts_dataset.d_model,
        dict_size=acts_dataset.d_model * expansion_factor,
        warmup_steps=warmup_steps,
        resample_steps=resample_steps,
        lr=lr,
        l1_penalty=l1_penalty,
        l1_annealing_pct=l1_annealing_pct,
        seed=seed,
        wandb_name=wandb_name,
        layer=layer,
        plm_name=plm_name,
        device=device,
        steps=min(steps, len(dataloader)),
    )
    print(f"Training with config: {trainer.config}")

    # Initialize fidelity function if evaluation sequences provided
    if eval_seq_path is not None:
        fidelity_fn = get_loss_recovery_fn(
            esm_model_name=plm_name,
            layer_idx=int(layer),
            eval_seq_path=eval_seq_path,
            device=device,
            batch_size=eval_batch_size,
        )
    else:
        fidelity_fn = None

    # Train the SAE
    train_run(
        # Core training components
        data=dataloader,
        trainer=trainer,
        # Evaluation settings
        fidelity_fn=fidelity_fn,
        eval_steps=eval_steps,
        # Logging and checkpointing
        save_dir=save_dir,
        log_steps=log_steps,
        save_steps=save_steps,
        max_ckpts_to_keep=3,
        # Weights & Biases configuration
        use_wandb=use_wandb,
        wandb_entity=wandb_entity,
        wandb_project=wandb_project,
        additional_wandb_args={
            "eval_seq_path": eval_seq_path,
            "eval_steps": eval_steps,
            "batch_size": batch_size,
            "save_dir": save_dir,
        },
    )

    # print(save_dir)

# %%
# Loop through all 12 layers and train SAE on each
for layer in range(12):
    gfm_embd_dir = f"/maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/activations/layer_{layer}"
    save_dir = f"/maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer{layer+1}"
    
    print(f"=== Training SAE on layer {layer} embeddings ===")
    train_SAE_on_gfm_embeds(
        gfm_embd_dir=gfm_embd_dir,
        save_dir=save_dir,
        wandb_entity="yunfei-hu-vanderbilt-university",
        steps=5000
    )
    print(f"Finished training SAE on layer {layer}, results saved to {save_dir}\n")
# Out:
# === Training SAE on layer 0 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 6452.28it/s]
# Using activations from layer layer_0 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_0', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: yunfei-hu (yunfei-hu-vanderbilt-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190602-kzospwjy</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/kzospwjy' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/kzospwjy' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/kzospwjy</a>
# 100%|██████████| 5000/5000 [00:12<00:00, 395.05it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▇▇▇▇▆▇▇▇█▇▇▇▅▆▇▃█▇▃▃▂▇▆▃▂▁▇▅▂▂▃▄▁▆▆▇▅▃▂▄</td></tr><tr><td>act_std</td><td>████▅▇█▇▇█▇▇█▆▇▇▆▇█▆▅▆▇▇▆▅▃▇▆▆▅▆▁▇▇▇▆▆▅▅</td></tr><tr><td>frac_variance_explained</td><td>▁▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇███  ███  ▇     █ ███   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▄▃▃▃▂▃▂▂▂▂▂▂▂▁▂▂▁▂▂▂▁▁▂▁▁▁▁▁▁▂▂▁▂▁▁▁▁</td></tr><tr><td>loss</td><td>█▅▅▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▁▁▂▂▂▁▁▁▂▁▁▁▁▁▁▂▂▂▂▁▁▁</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▃▃▂▂▂▂▂▁▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▂▂▂▂▂▂▂▃▂▂▃▂▂▂▂▁▁▂▂▂▂▁▂▂▂▁▂▂▂▂▁▂▂▂▂▁▂▁</td></tr><tr><td>reconstruction_std</td><td>█▂▁▃▂▄▄▅▄▅▆▆▅▄▅▆▆▆▆▆▅▆▅▆▇▅▅▆▆▅▆▆▇▅▆▆▆▆▆▆</td></tr><tr><td>sparsity_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00389</td></tr><tr><td>act_std</td><td>0.92017</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>5</td></tr><tr><td>l0_pct_nonzero</td><td>0.12207</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>3.49993</td></tr><tr><td>loss</td><td>4.84832</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>12.24949</td></tr><tr><td>reconstruction_mean</td><td>0.002</td></tr><tr><td>reconstruction_std</td><td>0.92046</td></tr><tr><td>sparsity_loss</td><td>13.48394</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/kzospwjy' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/kzospwjy</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190602-kzospwjy/logs</code>
# Finished training SAE on layer 0, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer1
#
# === Training SAE on layer 1 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7523.42it/s]
# Using activations from layer layer_1 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_1', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190616-n0tamduk</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n0tamduk' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n0tamduk' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n0tamduk</a>
# 100%|██████████| 5000/5000 [00:11<00:00, 429.18it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▄▅▆▅▆▇▅▆▇▆█▆▅▄▄▆▄▅▆▃▅█▆▅▆▁▆▇▅▅▇▇▆▁▇▆▅▅▆▇</td></tr><tr><td>act_std</td><td>▇▇▇▇▆▇▇▇▇▇▇▇▅▆█▅▇█▅▅▅██▅▅▂▇▅▄▅▅▅▅▁▆▇▇▆▆▄</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇███   ███  ▇    █ ████  </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▄▃▃▂▃▃▃▃▃▂▂▂▁▂▂▁▁▂▂▂▁▁▁▂▁▁▁▁▁▁▂▂▂▂▁▂▁</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▂▁▁▂▂▁▁▁▂▁▁▁▁▁▁▂▂▂▂▂▁▂▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▃▂▂▂▂▂▁▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▂▂▃▃▃▃▃▃▂▃▃▂▃▂▂▃▃▃▂▂▃▂▃▃▃▂▂▃▃▃▂▃▃▃▂▂▂▃</td></tr><tr><td>reconstruction_std</td><td>█▁▁▁▄▄▅▅▅▆▇▅▅▅▄▆▆▆▆▆▆▆▆▆▇▅▆▆▇▆▆▆▆▆▅▆▅▆▆▆</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00483</td></tr><tr><td>act_std</td><td>0.88966</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>5</td></tr><tr><td>l0_pct_nonzero</td><td>0.12207</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>4.00122</td></tr><tr><td>loss</td><td>5.41861</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>16.0098</td></tr><tr><td>reconstruction_mean</td><td>0.00552</td></tr><tr><td>reconstruction_std</td><td>0.89358</td></tr><tr><td>sparsity_loss</td><td>14.17385</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n0tamduk' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n0tamduk</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190616-n0tamduk/logs</code>
# Finished training SAE on layer 1, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer2
#
# === Training SAE on layer 2 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7559.57it/s]
# Using activations from layer layer_2 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_2', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190628-vk41b5ym</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/vk41b5ym' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/vk41b5ym' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/vk41b5ym</a>
# 100%|██████████| 5000/5000 [00:11<00:00, 441.42it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▂▂▂▄▃▄▂▃▄▃▄▂▂▂▄▅▄▃▆▃▄▂▅▇▆▄▆▅▇▄▇▇▁▃▅▄▅▄▇█</td></tr><tr><td>act_std</td><td>▇▅▇▆▇▆▆█▇▇▇▇▄▆█▅██▄▄██▅▅▄▇▅▄▅▄▅▅▁▆█▇▆▅▅▅</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▆▇▇▇▇▇▇▇▇▇▇▇███   ███       █ ██▇█   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▃▃▃▂▃▃▃▃▂▂▂▃▂▂▂▁▁▂▂▂▁▁▂▂▁▁▁▁▂▂▂▂▂▁▁▁▂</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▁▂▂▂▂▂▁▂▁▁▁▁▁▂▂▂▂▂▂▁▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▂▂▂▂▂▂▁▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▃▃▃▃▃▂▂▂▂▃▃▂▃▃▃▃▃▂▃▃▂▂▂▃▃▂▃▃▃▃▂▃▂▃▂▃▂▃</td></tr><tr><td>reconstruction_std</td><td>█▂▁▆▄▄▃▅▅▄▃▄▆▄▅▆▅▅▅▅▄▆▅▆▇▅▄▆▆▅▅▅▇▅▅▅▄▅▅▅</td></tr><tr><td>sparsity_loss</td><td>█▃▃▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▁▁▂▂▁▁▁▂▁▁▁▁▁▂▁▂▂▂▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00465</td></tr><tr><td>act_std</td><td>0.91629</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>6</td></tr><tr><td>l0_pct_nonzero</td><td>0.14648</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>5.34379</td></tr><tr><td>loss</td><td>6.86204</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>28.55607</td></tr><tr><td>reconstruction_mean</td><td>0.00391</td></tr><tr><td>reconstruction_std</td><td>0.96403</td></tr><tr><td>sparsity_loss</td><td>15.18251</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/vk41b5ym' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/vk41b5ym</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190628-vk41b5ym/logs</code>
# Finished training SAE on layer 2, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer3
#
# === Training SAE on layer 3 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 6871.21it/s]
# Using activations from layer layer_3 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_3', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190641-n4zzliiy</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n4zzliiy' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n4zzliiy' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n4zzliiy</a>
# 100%|██████████| 5000/5000 [00:11<00:00, 436.38it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▂▃▁▂▂▂▂▂▃▂▂▂▃▂▂▁▅▃▂▇▄█▄▂▆▆▄▄▄▆▇▇▇▅▂▃▃▃▆▆</td></tr><tr><td>act_std</td><td>▇▇▅▇▆█▆▆█▇▇▇▇▄▆▆▅▇█▅▄▅██▅▄▃▇▅▄▅▅▄▁▆▆▇▅▄▄</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇██▇   ██  █     █ ██▇█   </td></tr><tr><td>l0</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▃▃▃▃▂▃▃▃▃▂▂▂▃▂▂▂▁▁▂▂▁▁▂▂▁▁▁▁▂▁▂▂▂▂▂▂▁▂</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▃▁▁▂▂▃▁▁▂▂▁▁▁▂▁▂▂▂▃▂▂▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>██▅▄▅▄▄▄▄▄▄▃▃▃▄▂▂▁▁▂▂▃▁▁▂▃▁▁▁▁▂▂▂▃▂▃▂▂▁▂</td></tr><tr><td>reconstruction_mean</td><td>▇▁▃▄▄▄▅▄▄▄▄▄▄▄▅▄▅▄▄▄▇▄▄▅▃▅▅▅▄▆▄█▆▃▄▄▄▄▅▆</td></tr><tr><td>reconstruction_std</td><td>█▃▁▄▄▅▄▅▄▅▃▅▅▅▅▅▅▆▅▆▅▅▆▅▅▅▆▆▅▆▇▆▆▅▅▅▆▅▅▇</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00421</td></tr><tr><td>act_std</td><td>0.92976</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>5</td></tr><tr><td>l0_pct_nonzero</td><td>0.12207</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>5.78936</td></tr><tr><td>loss</td><td>7.35749</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>33.51672</td></tr><tr><td>reconstruction_mean</td><td>0.00482</td></tr><tr><td>reconstruction_std</td><td>0.99976</td></tr><tr><td>sparsity_loss</td><td>15.68131</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n4zzliiy' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/n4zzliiy</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190641-n4zzliiy/logs</code>
# Finished training SAE on layer 3, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer4
#
# === Training SAE on layer 4 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7422.23it/s]
# Using activations from layer layer_4 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_4', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190654-k0kjjfo9</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/k0kjjfo9' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/k0kjjfo9' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/k0kjjfo9</a>
# 100%|██████████| 5000/5000 [00:11<00:00, 447.12it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▂▄▂▃▂▂▂▃▃▃▃▁▂▃▂▂▆▄▇▄█▄▄▆█▆▄▅▆█▇▆▇▅▄▅▆▅▇▆</td></tr><tr><td>act_std</td><td>▇█▅▇▆█▆▆▇▇▇▇▇▅▆▅▆█▅▃▅▇█▅▄▃▇▃▅▅▃▅▁▆▇▇▅▃▅▃</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███   ███  █     █ ████ </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▁▂▂▂▂▂▂▂▂▁▁▂▂▂▂▂▂▃▂▂▂▂</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▁▂▂▂▃▂▂▂▃▁▁▂▁▂▂▂▃▂▃▂▁▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▃▂▃▂▃▃▂▂▄▃▄▃▃▃▃▃▃▄▃▄▃▃▃▄▄▅▃▃▄▄▄▁▃▃▃▃▃▃▃</td></tr><tr><td>reconstruction_std</td><td>█▃▁▃▃▂▃▃▂▃▄▄▃▃▄▄▃▄▅▅▄▄▃▄▄▄▄▅▅▄▄▄▅▄▄▄▃▅▄▅</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00309</td></tr><tr><td>act_std</td><td>0.94383</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>4</td></tr><tr><td>l0_pct_nonzero</td><td>0.09766</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>5.12539</td></tr><tr><td>loss</td><td>6.42295</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>26.26965</td></tr><tr><td>reconstruction_mean</td><td>0.00278</td></tr><tr><td>reconstruction_std</td><td>0.88373</td></tr><tr><td>sparsity_loss</td><td>12.97555</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/k0kjjfo9' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/k0kjjfo9</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190654-k0kjjfo9/logs</code>
# Finished training SAE on layer 4, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer5
#
# === Training SAE on layer 5 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 6964.00it/s]
# Using activations from layer layer_5 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_5', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190706-3xe453g9</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/3xe453g9' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/3xe453g9' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/3xe453g9</a>
# 100%|██████████| 5000/5000 [00:10<00:00, 464.44it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▃▁▃▃▄▂▂▃▃▃▂▂▄▁▄▇▃▄█▄▇▂▃▇▆▄▆█▇▇▅▇▂▄▃▃▅▇▇▇</td></tr><tr><td>act_std</td><td>▇▇▅▆▆▅▅▆▇▇▆▆▅▅█▄▆▇▅▃▆▆▇▅▄▄▇▅▃▅▆▃▆▁▆▆▇▃▄▄</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇███   ███  █    █ ██▇█   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▃▃▃▃▂▃▃▃▃▃▃▃▂▂▁▂▂▂▂▂▂▂▂▁▁▁▂▂▂▂▂▂▃▂▁▂▂</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▃▁▂▂▃▂▂▂▂▁▁▁▂▂▂▂▂▂▃▂▁▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▇▅▄▄▄▃▄▄▄▄▄▄▄▄▂▃▃▁▃▃▃▂▂▂▃▁▁▁▂▂▂▂▃▃▃▂▁▂▂</td></tr><tr><td>reconstruction_mean</td><td>█▁▁▁▃▃▃▃▃▃▃▃▃▃▃▃▄▃▃▃▃▃▃▃▂▃▃▅▄▄▃▃▃▂▃▃▃▃▂▄</td></tr><tr><td>reconstruction_std</td><td>█▄▁▅▃▃▂▄▃▄▄▄▄▃▄▅▄▄▅▃▄▄▅▅▆▄▆▅▅▄▆▄▅▄▃▄▄▅▄▆</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00302</td></tr><tr><td>act_std</td><td>0.95176</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>6</td></tr><tr><td>l0_pct_nonzero</td><td>0.14648</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>6.11162</td></tr><tr><td>loss</td><td>7.68239</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>37.35184</td></tr><tr><td>reconstruction_mean</td><td>0.00254</td></tr><tr><td>reconstruction_std</td><td>0.9676</td></tr><tr><td>sparsity_loss</td><td>15.70779</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/3xe453g9' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/3xe453g9</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190706-3xe453g9/logs</code>
# Finished training SAE on layer 5, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer6
#
# === Training SAE on layer 6 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7496.30it/s]
# Using activations from layer layer_6 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_6', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190718-jgez10dq</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/jgez10dq' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/jgez10dq' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/jgez10dq</a>
# 100%|██████████| 5000/5000 [00:10<00:00, 461.05it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▃▃▃▃▃▂▂▂▂▃▂▁▂▄▂▃▆▂▃▇▆█▂▂▅▅█▃▆▆▇▅▆▄▂▂▅▆▆▇</td></tr><tr><td>act_std</td><td>▇▅▆▆▇▅▆▆█▆▆▅▅█▆▅▇▅▂▅▅▇▅▃▂▆▅▃▅▆▂▆▁▆▅▇▄▃▄▄</td></tr><tr><td>frac_variance_explained</td><td>▁▃▄▅▄▄▆▅▆▆▆▆▅▆▆▇▇   ▇▆▇  ▇     █ ▇▇▇▇   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▃▃▃▃▂▃▃▃▃▃▃▃▂▂▂▁▂▂▂▃▂▁▂▂▁▁▁▂▂▂▂▂▃▂▁▁▂</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▃▃▃▃▂▃▃▁▂▂▃▃▂▁▂▁▁▁▁▂▂▂▃▂▃▂▁▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▇▆▄▅▅▄▄▄▄▅▄▄▄▄▂▃▃▁▂▂▃▂▂▂▃▁▁▁▁▂▂▂▃▃▄▂▁▁▂</td></tr><tr><td>reconstruction_mean</td><td>█▁▃▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▆▅▅▆▆▆▆▆▅▆▅▅▅▅▅▅▅</td></tr><tr><td>reconstruction_std</td><td>█▃▂▄▃▁▁▄▁▃▂▄▂▄▂▂▄▃▃▄▃▄▃▂▄▅▄▄▅▅▃▃▄▃▃▃▄▄▄▅</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00273</td></tr><tr><td>act_std</td><td>0.96754</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>6</td></tr><tr><td>l0_pct_nonzero</td><td>0.14648</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>6.33029</td></tr><tr><td>loss</td><td>7.74156</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>40.07251</td></tr><tr><td>reconstruction_mean</td><td>0.00093</td></tr><tr><td>reconstruction_std</td><td>0.95654</td></tr><tr><td>sparsity_loss</td><td>14.11276</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/jgez10dq' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/jgez10dq</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190718-jgez10dq/logs</code>
# Finished training SAE on layer 6, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer7
#
# === Training SAE on layer 7 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7652.44it/s]
# Using activations from layer layer_7 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_7', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190730-z1fc7ab7</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/z1fc7ab7' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/z1fc7ab7' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/z1fc7ab7</a>
# 100%|██████████| 5000/5000 [00:11<00:00, 440.81it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▂▂▂▄▃▂▁▂▂▃▂▂▃▃▁▆▂▃█▄▇▃▃▆▆▃▇▇▆▇▅▇▄▃▂▃▅▅▆█</td></tr><tr><td>act_std</td><td>▇▇▆▇▆▇▅▆▅▆▆▆▆▆▆▃▄▇▅▁█▅▆▅▃▆▄▂▆▆▂▆▅▆▅▆▆▂▅▅</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇███   ███  █     █ ███   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▄▄▃▃▃▃▂▃▃▂▃▃▃▃▃▂▂▂▁▁▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▁▁▂</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▁▂▂▃▃▂▂▂▃▂▁▂▂▂▂▂▃▂▃▂▁▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>▁▂▆▆▅▅▆▆▆▆▅▆▆▆▆▆▆▅▆▆▅█▆▆▆▆▆▅▆▇▇▆▆▇▅▆▆▅▄▆</td></tr><tr><td>reconstruction_std</td><td>█▄▂▃▃▄▁▂▅▄▄▄▄▃▅▅▄▃▅▅▄▄▄▄▅▄▅▅▅▄▃▄▄▄▄▄▄▅▄▅</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00268</td></tr><tr><td>act_std</td><td>0.98829</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>5</td></tr><tr><td>l0_pct_nonzero</td><td>0.12207</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>7.84433</td></tr><tr><td>loss</td><td>9.23009</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>61.53343</td></tr><tr><td>reconstruction_mean</td><td>0.00081</td></tr><tr><td>reconstruction_std</td><td>0.91032</td></tr><tr><td>sparsity_loss</td><td>13.85765</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/z1fc7ab7' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/z1fc7ab7</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190730-z1fc7ab7/logs</code>
# Finished training SAE on layer 7, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer8
#
# === Training SAE on layer 8 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 6926.82it/s]
# Using activations from layer layer_8 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_8', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190743-unmm3w95</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/unmm3w95' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/unmm3w95' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/unmm3w95</a>
# 100%|██████████| 5000/5000 [00:11<00:00, 449.89it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▄▄▅▅▇▄▃▅▅▅▄▅▂▄▄▅▃▇▁▇▅▆▆▅▃▄▄▆▄▆▆▇▆▅▅▆▅▄▅█</td></tr><tr><td>act_std</td><td>▂▃▅▃▂▃▂▂▃▂▂▁▃▃▁▁▂▂▂▄▄▃▂▂▃▆▂▄▅▂▅▃█▃▃▂▄▂▅▇</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█▇█   █▇█  █    █ █▇█   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▃▃▃▂▂▃▂▃▃▂▃▃▂▃▂▂▂▁▂▂▂▁▂▂▂▂▁▂▁▂▂▂▂▂▂▁▁▁▂</td></tr><tr><td>loss</td><td>█▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▃▂▁▂▂▂▃▂▂▂▂▂▁▂▂▂▂▂▂▃▃▂▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▃▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▃▄▄▄▄▄▄▄▄▄▅▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>reconstruction_std</td><td>█▄▁▄▄▅▃▃▂▄▄▅▃▅▄▄▅▄▃▅▄▄▅▅▆▅▄▅▅▄▅▅▄▄▄▄▅▆▅▆</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00014</td></tr><tr><td>act_std</td><td>1.0396</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>8</td></tr><tr><td>l0_pct_nonzero</td><td>0.19531</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>8.16932</td></tr><tr><td>loss</td><td>10.03732</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>66.73777</td></tr><tr><td>reconstruction_mean</td><td>-0.00044</td></tr><tr><td>reconstruction_std</td><td>1.05733</td></tr><tr><td>sparsity_loss</td><td>18.68003</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/unmm3w95' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/unmm3w95</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190743-unmm3w95/logs</code>
# Finished training SAE on layer 8, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer9
#
# === Training SAE on layer 9 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7016.23it/s]
# Using activations from layer layer_9 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_9', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190755-rz8u28co</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/rz8u28co' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/rz8u28co' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/rz8u28co</a>
# 100%|██████████| 5000/5000 [00:10<00:00, 464.32it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▆▄▅▆▆▅▃▃▅▄▆▂▅▄▄▆▂▅▅▅▅▆▅▆▆▁▇▄▂▅▄█▅▅▄▄▆▄▃▇</td></tr><tr><td>act_std</td><td>▂▄▅▂▄▂▂▃▅▃▄▁▅▃▂▂▃▄▃▃▂▂▅▃▂▅▄▃▅▄▁▆▄█▅▁▃▅▃▄</td></tr><tr><td>frac_variance_explained</td><td>▁▇▇▇██▇█▇█▇▇██▇████  ███  █     █ ███   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄▇█████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▃▃▃▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▁▂▂▂▂▁▂▂▁▁▁▂▂▂▂▂▂▁▁▁▂</td></tr><tr><td>loss</td><td>█▄▄▃▃▃▃▂▃▃▃▃▃▂▃▂▂▂▂▁▂▂▂▂▁▂▂▁▁▁▂▂▂▂▂▃▂▂▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▂▂▂▁▁▂▁▂▁▁▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▃▃▄▃▃▄▄▄▄▄▄▄▄▃▄▄▃▄▄▄▄▄▄▄▄▄▄▄▄▃▄▄▄▄▃▄▄▄</td></tr><tr><td>reconstruction_std</td><td>█▃▁▆▅▂▃▅▃▃▅▃▅▄▃▆▄▃▅▄▄▄▅▆▅▅▄▅▅▅▆▅▄▄▅▄▆▅▆▆</td></tr><tr><td>sparsity_loss</td><td>█▂▃▂▂▂▂▂▂▁▂▁▂▂▁▂▂▁▁▁▁▂▂▁▁▁▂▁▁▁▁▁▁▂▁▂▂▂▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00146</td></tr><tr><td>act_std</td><td>1.09142</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>7</td></tr><tr><td>l0_pct_nonzero</td><td>0.1709</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>7.29748</td></tr><tr><td>loss</td><td>9.42276</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>53.25319</td></tr><tr><td>reconstruction_mean</td><td>0.00254</td></tr><tr><td>reconstruction_std</td><td>1.05683</td></tr><tr><td>sparsity_loss</td><td>21.25286</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/rz8u28co' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/rz8u28co</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190755-rz8u28co/logs</code>
# Finished training SAE on layer 9, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer10
#
# === Training SAE on layer 10 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7790.31it/s]
# Using activations from layer layer_10 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_10', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190807-9grnkbri</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/9grnkbri' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/9grnkbri' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/9grnkbri</a>
# 100%|██████████| 5000/5000 [00:10<00:00, 464.73it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▆▅▅▆▆▅▃▅▅▅▆▃▄▄▆▄▅▆▇▃▅▆▅▇▄█▆▄▆▄▄▆▆▅▆▇▅▁▃▇</td></tr><tr><td>act_std</td><td>▃▅▆▄▆▅▅▇▄▅▄▅▄▄▃▃▆▄▂▄▆▆▂▅▅▅▃▆▅▁▇▅▇▇▇▅▅▂▆█</td></tr><tr><td>frac_variance_explained</td><td>▁▆▆▇▇█▇▇▇▇▇▇▇█▇█▇▇█   ███      █ ███▇   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▆██████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁▂▂▁▁▂▂▁▂▂▂▂▁▁▁</td></tr><tr><td>loss</td><td>█▃▃▃▂▂▂▂▂▂▃▃▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁▂▁▁▂▂▂▂▂▂▂▁▁▁</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▂</td></tr><tr><td>reconstruction_std</td><td>█▂▃▅▃▂▃▆▄▃▇▃▃▄▂▇▄▁▅▂▄▅▄▃▅▄▃▄▄▃▅▃▅▅▅▅▅▄▄▆</td></tr><tr><td>sparsity_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.00741</td></tr><tr><td>act_std</td><td>1.17281</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>8</td></tr><tr><td>l0_pct_nonzero</td><td>0.19531</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>5.4065</td></tr><tr><td>loss</td><td>7.7136</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>29.23024</td></tr><tr><td>reconstruction_mean</td><td>0.00576</td></tr><tr><td>reconstruction_std</td><td>1.16535</td></tr><tr><td>sparsity_loss</td><td>23.07103</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/9grnkbri' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/9grnkbri</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190807-9grnkbri/logs</code>
# Finished training SAE on layer 10, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer11
#
# === Training SAE on layer 11 embeddings ===
# Loading dataset metadata
# 100%|██████████| 60/60 [00:00<00:00, 7562.07it/s]
# Using activations from layer layer_11 of scgpt
# Loaded dataset with 30,588,064 tokens
# Training with config: {'dict_class': 'AutoEncoder', 'trainer_class': 'StandardTrainer', 'activation_dim': 512, 'dict_size': 4096, 'lr': 0.001, 'l1_penalty': 0.1, 'l1_annealing_steps': 250, 'steps': 5000, 'warmup_steps': 50, 'resample_steps': None, 'device': 'cuda', 'layer': 'layer_11', 'plm_name': 'scgpt', 'wandb_name': 'SAE', 'submodule_name': None}
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/maiziezhou_lab2/yunfei/Projects/interpTFM/train/wandb/run-20250903_190819-1nm91li7</code>
# Syncing run <strong><a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/1nm91li7' target="_blank">SAE</a></strong> to <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a>
#  View run at <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/1nm91li7' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/1nm91li7</a>
# 100%|██████████| 5000/5000 [00:10<00:00, 455.24it/s]
# Stopped training because reached max specified steps
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>▆▆▅▆▆██▇█▆▆▇▇▆▆▄█▆▃▆▃▇█▄▆▁▆▅▃▅▅▄▄▆█▅▄▆▅▃</td></tr><tr><td>act_std</td><td>▅▁▅▂▂▃▄▂▄▂▄▅▆▅▅▃▄▄█▄▂▃▅▃▄▃▄▂▂▆▁▃▂▂▂▃▃▇▂▁</td></tr><tr><td>frac_variance_explained</td><td>▁▆▇▇▇▇▇▇▇▇▇▇▇▇▇██▇█   ▇▇█  █    █ ▇▇█   </td></tr><tr><td>l0</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l0_pct_nonzero</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>l1_penalty</td><td>▁▄██████████████████████████████████████</td></tr><tr><td>l2_loss</td><td>█▃▃▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▁▂▂▂▁▁▂▂▁▁▁▁▂▂▂▂▂▂▂▂▁▂</td></tr><tr><td>loss</td><td>█▃▃▃▂▂▃▂▂▃▃▃▂▂▂▂▂▂▂▁▂▂▂▂▁▂▁▁▁▁▂▂▂▂▂▂▂▁▁▂</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>mse_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_mean</td><td>█▁▇▁▄▄▃▄▅▅▃▃▆▅▅▆▄▄▄▄▄▄▄▅▄▃▅▄▄▅▅▄▄▄▅▄▅▆▅▅</td></tr><tr><td>reconstruction_std</td><td>█▁▃▃▄▄▄▃▄▅▆▄▄▅▅▄▃▃▄▄▄▄▅▅▄▄▅▄▅▄▆▄▄▄▄▂▄▃▄▆</td></tr><tr><td>sparsity_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>act_mean</td><td>0.01647</td></tr><tr><td>act_std</td><td>0.97184</td></tr><tr><td>frac_variance_explained</td><td>nan</td></tr><tr><td>l0</td><td>10</td></tr><tr><td>l0_pct_nonzero</td><td>0.24414</td></tr><tr><td>l1_penalty</td><td>0.1</td></tr><tr><td>l2_loss</td><td>4.72196</td></tr><tr><td>loss</td><td>6.72394</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mse_loss</td><td>22.29695</td></tr><tr><td>reconstruction_mean</td><td>0.01687</td></tr><tr><td>reconstruction_std</td><td>1.02966</td></tr><tr><td>sparsity_loss</td><td>20.01974</td></tr><tr><td>tokens</td><td>156800</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAE</strong> at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/1nm91li7' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging/runs/1nm91li7</a><br> View project at: <a href='https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging' target="_blank">https://wandb.ai/yunfei-hu-vanderbilt-university/test_logging</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250903_190819-1nm91li7/logs</code>
# Finished training SAE on layer 11, results saved to /maiziezhou_lab2/yunfei/Projects/interpTFM/activations_cosmx_lung_cancer/sae_latents/sae_output_layer12

# %%
# train_SAE_on_gfm_embeds(gfm_embd_dir='/maiziezhou_lab2/yunfei/Projects/FM_temp/InterPLM/interplm/scgpt/activations/layer_4', 
#                         save_dir='/maiziezhou_lab2/yunfei/Projects/FM_temp/interGFM/sae/sae_output_layer4',
#                         wandb_entity="yunfei-hu-vanderbilt-university",
#                         steps=5000)
